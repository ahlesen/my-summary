# %% [markdown]
# # Homework: Basic Artificial Neural Networks

# %% [markdown]
# The goal of this homework is simple, yet an actual implementation may take some time :). We are going to write an Artificial Neural Network (almost) from scratch. The software design was heavily inspired by [PyTorch](http://pytorch.org) which is the main framework of our course

# %% [markdown]
# This homework requires sending **multiple** files, please do not forget to include all the files when sending to TA. The list of files:
# - This notebook  - ***13 points***
# - homework_modules.ipynb with all blocks implemented (except maybe `Conv2d` and `MaxPool2d` layers implementation which are part of 'advanced' version of this homework)
# - homework_differentiation.ipynb -  ***2 points***

# %%
# %matplotlib inline
from time import time, sleep
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# # Framework

# %% [markdown]
# Implement everything in `Modules.ipynb`. Read all the comments thoughtfully to ease the pain. Please try not to change the prototypes.
#
# Do not forget, that each module should return **AND** store `output` and `gradInput`.
#
# The typical assumption is that `module.backward` is always executed after `module.forward`,
# so `output` is stored, this would be useful for `SoftMax`.

# %% [markdown]
# ### Tech note
# Prefer using `np.multiply`, `np.add`, `np.divide`, `np.subtract` instead of `*`,`+`,`/`,`-` for better memory handling.
#
# Example: suppose you allocated a variable
#
# ```
# a = np.zeros(...)
# ```
# So, instead of
# ```
# a = b + c  # will be reallocated, GC needed to free
# ```
# You can use:
# ```
# np.add(b,c,out = a) # puts result in `a`
# ```

# %%
# (re-)load layers
# %run homework_modules.ipynb

# %% [markdown]
# # Toy example

# %% [markdown]
# Use this example to debug your code, start with logistic regression and then test other layers. You do not need to change anything here. This code is provided for you to test the layers. Also it is easy to use this code in MNIST task.

# %%
# Generate some data
N = 500

X1 = np.random.randn(N,2) + np.array([2,2])
X2 = np.random.randn(N,2) + np.array([-2,-2])

Y = np.concatenate([np.ones(N),np.zeros(N)])[:,None]
Y = np.hstack([Y, 1-Y])

X = np.vstack([X1,X2])
plt.scatter(X[:,0],X[:,1], c = Y[:,0], edgecolors= 'none')

# %% [markdown]
# Define a **logistic regression** for debugging.

# %%
net = Sequential()
net.add(Linear(2, 2))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)

# Test something like that then 

# net = Sequential()
# net.add(Linear(2, 4))
# net.add(ReLU())
# net.add(Linear(4, 2))
# net.add(LogSoftMax())
# Out:
# Linear 2 -> 2
# LogSoftMax

# %% [markdown]
# Start with batch_size = 1000 to make sure every step lowers the loss, then try stochastic version.

# %%
# Iptimizer params
optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
optimizer_state = {}

# Looping params
n_epoch = 20
batch_size = 128

# %%
# batch generator
def get_batches(dataset, batch_size):
    X, Y = dataset
    n_samples = X.shape[0]
        
    # Shuffle at the start of epoch
    indices = np.arange(n_samples)
    np.random.shuffle(indices)
    
    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        
        batch_idx = indices[start:end]
    
        yield X[batch_idx], Y[batch_idx]

# %% [markdown]
# ### Train

# %% [markdown]
# Basic training loop. Examine it.

# %%
loss_history = []

for i in range(n_epoch):
    for x_batch, y_batch in get_batches((X, Y), batch_size):
        
        net.zeroGradParameters()
        
        # Forward
        predictions = net.forward(x_batch)
        loss = criterion.forward(predictions, y_batch)
    
        # Backward
        dp = criterion.backward(predictions, y_batch)
        net.backward(x_batch, dp)
        
        # Update weights
        sgd_momentum(net.getParameters(), 
                     net.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)      
        
        loss_history.append(loss)

    # Visualize
    display.clear_output(wait=True)
    plt.figure(figsize=(8, 6))
        
    plt.title("Training loss")
    plt.xlabel("#iteration")
    plt.ylabel("loss")
    plt.plot(loss_history, 'b')
    plt.show()
    
    print('Current loss: %f' % loss)
# Out:
# Current loss: 0.001313

# %% [markdown]
# # Digit classification

# %% [markdown]
# We are using old good [MNIST](http://yann.lecun.com/exdb/mnist/) as our dataset.

# %%
import mnist
X_train, y_train, X_val, y_val, X_test, y_test = mnist.load_dataset(flatten=True)

# %% [markdown]
# One-hot encode the labels first.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score

encoder = OneHotEncoder(categories=[range(10)], sparse=False)
y_enc_train = encoder.fit_transform(y_train.reshape(-1, 1))
y_enc_test = encoder.fit_transform(y_test.reshape(-1, 1))
y_enc_val = encoder.fit_transform(y_val.reshape(-1, 1))

# %% [markdown]
# - **Compare** `ReLU`, `ELU`, `LeakyReLU`, `SoftPlus` activation functions.
# You would better pick the best optimizer params for each of them, but it is overkill for now. Use an architecture of your choice for the comparison. Write your personal opinion on the activation functions, think about computation times too. Plot the losses both from activation functions comparison comparison on one plot. Please find a scale (log?) when the lines are distinguishable, do not forget about naming the axes, the plot should be goodlooking. ***2.5 points***
# - **Try** inserting `BatchNormalization` (folowed by `ChannelwiseScaling`) between `Linear` module and activation functions. Plot the losses both for the `BatchNormalization` comparison on one plot. Please find a scale (log?) when the lines are distinguishable, do not forget about naming the axes, the plot should be goodlooking.  Does `BatchNormalization` help? ***2.5 points***
#
# - Plot the losses for two networks: one trained by momentum_sgd, another one trained by Adam. Which one performs better? ***2.5 points***
# - Increase the number of parameters in the network. Try inserting the Dropout layer. Compare the validation performance and the gap between test and validation performances for the two experiments (with and without Dropout). Compare the loss plots. Which one converges slower? ***2.5 points***

# %% [markdown]
# ## Comparing activation functions

# %%
from time import time
def nnet(activation=ReLU()):
    net = Sequential()
    net.add(Linear(784, 512))
    net.add(activation)
    net.add(Linear(512, 256))
    net.add(activation)
    net.add(Linear(256, 128))
    net.add(activation)
    net.add(Linear(128, 64)) 
    net.add(activation)
    net.add(Linear(64, 10))
    net.add(LogSoftMax())
    
    criterion = ClassNLLCriterion()
    
    n_epoch = 10
    batch_size = 256
    
    optimizer_config = {'learning_rate' : 1e-2, 'momentum': 0.9}
    optimizer_state = {}
    
    train_loss_history = []
#     test_loss_history = []
    accuracy = []
    
    start_time= time()
    for i in range(n_epoch):
        train_loss_epoch = []
        for x_batch, y_batch in get_batches((X_train, y_enc_train), batch_size):
            net.zeroGradParameters()
        
            # Forward
            predictions = net.forward(x_batch)
            loss = criterion.forward(predictions, y_batch)
    
            # Backward
            dp = criterion.backward(predictions, y_batch)
            net.backward(x_batch, dp)
        
            # Update weights
            sgd_momentum(net.getParameters(), 
                     net.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)      
        
            train_loss_epoch.append(loss)
        
        # Test prediction & Accuracy
        net.evaluate()
        y_test_pred = net.forward(X_test)
        test_loss = criterion.forward(y_test_pred,y_enc_test)
        accuracy_epoch = accuracy_score(np.argmax(y_enc_test, axis=1),np.argmax(y_test_pred,axis=1))
        accuracy.append(accuracy_epoch)
#       test_loss_history.append(test_loss)
    
        train_loss_history.append(np.mean(train_loss_epoch))
      
    end_time = time()-start_time
    return train_loss_history, loss, np.mean(accuracy), end_time

# %% [markdown]
# Here I used better learning rate = 1e-1 but in other situations I take learning rate = 1e-2 for better comprasion of BN(on SoftPlus)

# %%
activations = [ReLU(), ELU(), LeakyReLU(), SoftPlus()]
plt.figure(figsize=(15, 9))
plt.title('Training loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.xlim(0,9)

for activ in activations:
    train_history, loss, accuracy,time_act = nnet(activ)
    print('NN with {0}: loss = {1:.3}\t accuracy = {2:.3}\t time = {3:.3}'.format(activ,loss,accuracy,time_act))
    plt.semilogy(train_history, label = '{}'.format(activ))
plt.legend()
plt.show()
# Out:
# NN with ReLU: loss = 0.00208	 accuracy = 0.965	 time = 43.0
# NN with ELU: loss = 0.0272	 accuracy = 0.957	 time = 84.6
# NN with LeakyReLU: loss = 0.0664	 accuracy = 0.966	 time = 45.2
# NN with SoftPlus: loss = 0.218	 accuracy = 0.807	 time = 85.7

# %% [markdown]
# ## Opinion
#
# There we have two best active function: LeakyReLU and ReLU  wuth the best accuracy score and values of loss function

# %% [markdown]
# ## Comparing activation functions with BatchNormalization

# %%
def nnet_with_batch(activation=ReLU()):
    net = Sequential()
    net.add(Linear(784, 512))
    net.add(BatchNormalization())
    net.add(ChannelwiseScaling(512))
    net.add(activation)
    net.add(Linear(512, 256))
    net.add(BatchNormalization())
    net.add(ChannelwiseScaling(256))
    net.add(activation)
    net.add(Linear(256, 128))
    net.add(BatchNormalization())
    net.add(ChannelwiseScaling(128))
    net.add(activation)
    net.add(Linear(128, 64)) 
    net.add(BatchNormalization())
    net.add(ChannelwiseScaling(64))
    net.add(activation)
    net.add(Linear(64, 10))
    net.add(BatchNormalization())
    net.add(ChannelwiseScaling(10))
    net.add(LogSoftMax())
    
    
    criterion = ClassNLLCriterion()
    
    n_epoch = 10
    batch_size = 256
    
    optimizer_config = {'learning_rate' : 1e-2, 'momentum': 0.9}
    optimizer_state = {}
    
    train_loss_history = []
#     test_loss_history = []
    accuracy = []
    
    start_time= time()
    for i in range(n_epoch):
        train_loss_epoch = []
        for x_batch, y_batch in get_batches((X_train, y_enc_train), batch_size):
            net.zeroGradParameters()
        
            # Forward
            predictions = net.forward(x_batch)
            loss = criterion.forward(predictions, y_batch)
    
            # Backward
            dp = criterion.backward(predictions, y_batch)
            net.backward(x_batch, dp)
        
            # Update weights
            sgd_momentum(net.getParameters(), 
                     net.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)      
        
            train_loss_epoch.append(loss)
        
        # Test prediction & Accuracy
        net.evaluate()
        y_test_pred = net.forward(X_test)
        test_loss = criterion.forward(y_test_pred,y_enc_test)
        accuracy_epoch = accuracy_score(np.argmax(y_enc_test, axis=1),np.argmax(y_test_pred,axis=1))
        accuracy.append(accuracy_epoch)
#             test_loss_history.append(test_loss)
    
        train_loss_history.append(np.mean(train_loss_epoch))
      
    end_time = time()-start_time
    return train_loss_history, loss, np.mean(accuracy), end_time

# %%
activations = [ReLU(), ELU(), LeakyReLU(), SoftPlus()]
plt.figure(figsize=(15, 9))
plt.title('Training loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.xlim(0,9)

for activ in activations:
    train_history, loss, accuracy,time_act = nnet_with_batch(activ)
#     print((train_history),'\n',(loss),'\n',(accuracy),'\n',(time_act))
    print('NN with {0} and BN: loss = {1:.3}\t accuracy = {2:.3}\t time = {3:5.3}'.format(activ,loss,accuracy,time_act))
    plt.semilogy(train_history, label = '{} with BN'.format(activ))
plt.legend()
plt.show()
# Out:
# NN with ReLU and BN: loss = 0.00951	 accuracy = 0.97	 time =  66.8
# NN with ELU and BN: loss = 0.0787	 accuracy = 0.932	 time = 1.14e+02
# NN with LeakyReLU and BN: loss = 0.00714	 accuracy = 0.971	 time =  96.1
# NN with SoftPlus and BN: loss = 5.28	 accuracy = 0.573	 time = 1.6e+02

# %%
activations = [ReLU(), ELU(), LeakyReLU(), SoftPlus()]
plt.figure(figsize=(18, 9))

plt.xlim(0,9)
subplot = 140

for activ in activations:
    subplot +=1
    plt.subplot(subplot)
    train_history, loss, accuracy,time_act = nnet(activ)
    print('NN with {0}: loss = {1:.3}\t accuracy = {2:.3}\t time = {3:.3}'.format(activ,loss,accuracy,time_act))
    plt.semilogy(train_history, label = '{}'.format(activ))
    
    train_history_b, loss_b, accuracy_b,time_act_b = nnet_with_batch(activ)
    print('NN with {0} and BN: loss = {1:.3}\t accuracy = {2:.3}\t time = {3:5.3}'.format(activ,loss_b,accuracy_b,time_act_b))
    plt.semilogy(train_history_b, label = '{} with BN'.format(activ), linestyle='--')
    plt.title('{}'.format(activ))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend()
plt.show()
# Out:
# NN with ReLU: loss = 0.0992	 accuracy = 0.873	 time = 40.0
# NN with ReLU and BN: loss = 0.00807	 accuracy = 0.971	 time =  63.1
# NN with ELU: loss = 0.116	 accuracy = 0.917	 time = 87.4
# NN with ELU and BN: loss = 0.154	 accuracy = 0.938	 time = 1.04e+02
# NN with LeakyReLU: loss = 0.169	 accuracy = 0.871	 time = 48.7
# NN with LeakyReLU and BN: loss = 0.01	 accuracy = 0.971	 time =  74.0
# NN with SoftPlus: loss = 0.544	 accuracy = 0.626	 time = 90.4
# NN with SoftPlus and BN: loss = 3.82	 accuracy = 0.704	 time = 1.1e+02

# %%
activations = [ReLU(), ELU(), LeakyReLU(), SoftPlus()]
plt.figure(figsize=(18, 9))

plt.xlim(0,9)
subplot = 140

for activ in activations:
    subplot +=1
    plt.subplot(subplot)
    train_history, loss, accuracy,time_act = nnet(activ)
    print('NN with {0}: loss = {1:.3}\t accuracy = {2:.3}\t time = {3:.3}'.format(activ,loss,accuracy,time_act))
    plt.semilogy(train_history, label = '{}'.format(activ))
    
    train_history_b, loss_b, accuracy_b,time_act_b = nnet_with_batch(activ)
    print('NN with {0} and BN: loss = {1:.3}\t accuracy = {2:.3}\t time = {3:5.3}'.format(activ,loss_b,accuracy_b,time_act_b))
    plt.semilogy(train_history_b, label = '{} with BN'.format(activ), linestyle='--')
    plt.title('{}'.format(activ))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend()
plt.show()
# Out:
# NN with ReLU: loss = 0.0249	 accuracy = 0.88	 time = 43.2
# NN with ReLU and BN: loss = 0.0329	 accuracy = 0.971	 time =  85.7
# NN with ELU: loss = 0.13	 accuracy = 0.923	 time = 93.6
# NN with ELU and BN: loss = 0.149	 accuracy = 0.94	 time = 1.07e+02
# NN with LeakyReLU: loss = 0.114	 accuracy = 0.892	 time = 50.5
# NN with LeakyReLU and BN: loss = 0.0141	 accuracy = 0.972	 time =  70.3
# NN with SoftPlus: loss = 0.278	 accuracy = 0.59	 time = 86.9
# NN with SoftPlus and BN: loss = 0.572	 accuracy = 0.812	 time = 1.11e+02

# %% [markdown]
# ## Opinion
#
# As we can see for every activation function BN help to increase accuracy.
# And as in previous step the best activation functions are ReLu and LeakyReLu

# %% [markdown]
# ## Comparing networks: with momentum_sgd, with Adam.

# %%
def nnet_adam(activation=ReLU(), adam=True):
    net = Sequential()
    net.add(Linear(784, 512))
    net.add(activation)
    net.add(Linear(512, 256))
    net.add(activation)
    net.add(Linear(256, 128))
    net.add(activation)
    net.add(Linear(128, 64)) 
    net.add(activation)
    net.add(Linear(64, 10))
    net.add(LogSoftMax())
    
    criterion = ClassNLLCriterion()
    
    n_epoch = 10
    batch_size = 256
    
    
    
    train_loss_history = []
#     test_loss_history = []
    accuracy = []
    
    if(adam):
        optimizer_config = {'learning_rate' : 1e-1, 'beta1': 0.9, 'beta2':0.99,'epsilon':1e-2}
        optimizer_state = {}
    else:
        optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
        optimizer_state = {}
    
    start_time= time()
    for i in range(n_epoch):
        train_loss_epoch = []
        for x_batch, y_batch in get_batches((X_train, y_enc_train), batch_size):
            net.zeroGradParameters()
        
            # Forward
            predictions = net.forward(x_batch)
            loss = criterion.forward(predictions, y_batch)
    
            # Backward
            dp = criterion.backward(predictions, y_batch)
            net.backward(x_batch, dp)
            
            # Update weights
            if(adam):
                adam_optimizer(net.getParameters(), 
                     net.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)
            else:  
                sgd_momentum(net.getParameters(), 
                     net.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)      
        
            train_loss_epoch.append(loss)
        
        # Test prediction & Accuracy
        net.evaluate()
        y_test_pred = net.forward(X_test)
        test_loss = criterion.forward(y_test_pred,y_enc_test)
        accuracy_epoch = accuracy_score(np.argmax(y_enc_test, axis=1),np.argmax(y_test_pred,axis=1))
        accuracy.append(np.mean(accuracy_epoch))
#       test_loss_history.append(test_loss)
    
        train_loss_history.append(np.mean(train_loss_epoch))
      
    end_time = time()-start_time
    return train_loss_history, loss, np.mean(accuracy), end_time

# %%
activations = [ReLU(), ELU(), LeakyReLU()]# withput SoftPLus sorry fotthat I have not enough time
plt.figure(figsize=(15, 9))
plt.title('Training loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.xlim(0,9)

for activ in activations:
    train_history, loss, accuracy,time_act = nnet_adam(activ,adam=False)
#     print((train_history),'\n',(loss),'\n',(accuracy),'\n',(time_act))
    print('NN with {0} SGD: loss = {1:.3}\t accuracy = {2:.3}\t time ={3:5.3}'.format(activ,loss,accuracy,time_act))
    plt.semilogy(train_history, label = '{} with SGD'.format(activ),linestyle='--')
    train_history_ad, loss_ad, accuracy_ad,time_act_ad = nnet_adam(activ,adam=True)
    print('NN with {0} ADAM: loss = {1:.3}\t accuracy = {2:.3}\t time ={3:5.3}'.format(activ,loss_ad,accuracy_ad,time_act_ad))
    plt.semilogy(train_history_ad, label = '{} with ADAM'.format(activ))
plt.legend()
plt.show()
# Out:
# NN with ReLU SGD: loss = 0.000939	 accuracy = 0.97	 time = 51.4
# NN with ReLU ADAM: loss = 0.0023	 accuracy = 0.969	 time = 63.3
# NN with ELU SGD: loss = 0.0933	 accuracy = 0.958	 time =1.13e+02

# %%
activations = [ReLU(), ELU(), LeakyReLU(), SoftPlus()]
plt.figure(figsize=(18, 9))

plt.xlim(0,9)
subplot = 140

for activ in activations:
    subplot +=1
    plt.subplot(subplot)
    train_history, loss, accuracy,time_act = nnet_adam(activ,adam=False)
    print('NN with {0} SGD: loss = {1:.3}\t accuracy = {2:.3}\t time ={3:5.3}'.format(activ,loss,accuracy,time_act))
    plt.plot(accuracy, label = '{} with SGD'.format(activ),linestyle='--')
    train_history_ad, loss_ad, accuracy_ad,time_act_ad = nnet_adam(activ,adam=True)
    print('NN with {0} ADAM: loss = {1:.3}\t accuracy = {2:.3}\t time ={3:5.3}'.format(activ,loss_ad,accuracy_ad,time_act_ad))
    plt.plot(accuracy_ad, label = '{} with ADAM'.format(activ))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend()
plt.show()

# %% [markdown]
# ## Opinion
#
# As we should see for every activation function ADAM optimization increase accuracy.
#
# I made it before new recalculation

# %% [markdown]
# ## Network with and without Dropout.

# %%
def nnet_dropout(activation=ReLU(), dropout=True):
    net = Sequential()
#     net.add(Linear(784, 128))
#     net.add(Linear(784, 256))
#     net.add(BatchNormalization())
#     net.add(ChannelwiseScaling(256))
#     net.add(activation)
#     net.add(Dropout())
#     net.add(Linear(256, 128))
#     net.add(BatchNormalization())
#     net.add(ChannelwiseScaling(128))
#     net.add(activation)
#     net.add(Linear(128, 64)) 
#     net.add(BatchNormalization())
#     net.add(ChannelwiseScaling(64))
#     net.add(activation)
#     net.add(Linear(64, 32))
#     net.add(BatchNormalization())
#     net.add(ChannelwiseScaling(32))
#     net.add(activation)
#     net.add(Linear(32, 10))
#     net.add(BatchNormalization())
#     net.add(ChannelwiseScaling(10))
#     net.add(LogSoftMax())
    
    net.add(Linear(784, 512))
    net.add(activation)
    if dropout:
        net.add(Dropout())
    net.add(Linear(512, 256))
    net.add(activation)
    net.add(Linear(256, 128))
    net.add(activation)
    net.add(Linear(128, 64)) 
    net.add(activation)
    net.add(Linear(64, 10))
    net.add(LogSoftMax())
    
    criterion = ClassNLLCriterion()
    
    n_epoch = 10
    batch_size = 256
    
    
    
    train_loss_history = []
    test_loss_history = []
    val_loss_history =  []
    accuracy_test = []
    accuracy_val = []
    

    optimizer_config = {'learning_rate' : 1e-2, 'momentum': 0.8}
    optimizer_state = {}
    
    for i in range(n_epoch):
        train_loss_epoch = []
        for x_batch, y_batch in get_batches((X_train, y_enc_train), batch_size):
            net.zeroGradParameters()
        
            # Forward
            predictions = net.forward(x_batch)
            loss = criterion.forward(predictions, y_batch)
    
            # Backward
            dp = criterion.backward(predictions, y_batch)
            net.backward(x_batch, dp)
            
            # Update weights
            sgd_momentum(net.getParameters(), 
                     net.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)      
        
            train_loss_epoch.append(loss)
        
        # Test prediction & Accuracy
        net.evaluate()
        y_test_pred = net.forward(X_test)
        
        test_loss = criterion.forward(y_test_pred,y_enc_test)
        accuracy_epoch = accuracy_score(np.argmax(y_enc_test, axis=1),np.argmax(y_test_pred,axis=1))
        accuracy_test.append(accuracy_epoch)
        
        y_val_pred = net.forward(X_val)
        
        val_loss = criterion.forward(y_val_pred,y_enc_val)
        accuracy_epoch = accuracy_score(np.argmax(y_enc_val, axis=1),np.argmax(y_val_pred,axis=1))
        accuracy_val.append(accuracy_epoch)
        
        test_loss_history.append(np.mean(test_loss))
    
        val_loss_history.append(np.mean(val_loss))
      
    return test_loss_history, val_loss_history, accuracy_test, accuracy_val

# %%
activations = [ReLU(), ELU(), LeakyReLU(), SoftPlus()]
plt.figure(figsize=(15, 9))
subplot = 140
for activ in activations:
    subplot +=1
    plt.subplot(subplot)
    test_history, val_history, accuracy_test, accuracy_val = nnet_dropout(activ,dropout=True)
    plt.semilogy(test_history, label = '{} test loss with'.format(activ))
    plt.semilogy(val_history, label = '{} val loss with'.format(activ),linestyle='--')
    test_history, val_history, accuracy_test, accuracy_val = nnet_dropout(activ,dropout=False)
    plt.semilogy(test_history, label = '{} test loss without'.format(activ))
    plt.semilogy(val_history, label = '{} val loss without'.format(activ),linestyle='o-')
    plt.title('{} with Dropout'.format(activ))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend()
plt.show()

# %%
activations = [ReLU(), ELU(), LeakyReLU(), SoftPlus()]
plt.figure(figsize=(15, 9))
subplot = 140
for activ in activations:
    subplot +=1
    plt.subplot(subplot)
    test_history, val_history, accuracy_test, accuracy_val = nnet_dropout(activ, dropout=True)
    plt.plot(accuracy_test, label = '{} test accuracy with'.format(activ))
    plt.plot(accuracy_val, label = '{} val accuracy with'.format(activ),linestyle='--')
    test_history, val_history, accuracy_test, accuracy_val = nnet_dropout(activ, dropout=False)
    plt.plot(accuracy_test, label = '{} test accuracy without'.format(activ))
    plt.plot(accuracy_val, label = '{} val accuracy without'.format(activ),linestyle='--')
    plt.title('{} with Dropout'.format(activ))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend()
plt.show()

# %% [markdown]
# # Learning embeddings

# %% [markdown]
# **Finally**, use the Contrastive criterion instead of the NLLCriterion to train the embeddings.
# Using the code below, compute the pairwise distances and show the distance histograms for the validation set (or its part). Compute the Bhattacharyya coefficient using the outputs of the plt.hist: $ BC(p,q) = \sum (\sqrt{p_i q_i}) $.
#
# Repeat this for the embeddings trained with the NLLCriterion, compare the results. You may want to try different margins $M$ (hint: $M=10$ should be okay).
#
#  ***3 points***

# %%
loss_history = []
optimizer_config = {'learning_rate' : 1e-7, 'momentum': 0.8}
optimazer_state = {}
net = Sequential()
net.add(Linear(784, 512))
net.add(ReLU())
net.add(Dropout())
net.add(Linear(256, 128))
net.add(ReLU())
net.add(Linear(128, 10))
# net.add(LogSoftMax())

criterion = ClassContrastiveCriterion(10)
n_epoch = 10
batch_size = 20

for i in range(n_epoch):
    loss_epoch = []
    for x_batch, y_batch in get_batches((X_train, y_train), batch_size):
        net.zeroGradParameters()
        
        # Forward
        predictions = net.forward(x_batch)
        loss = criterion.forward(predictions, y_batch)
    
        # Backward
        dp = criterion.backward(predictions, y_batch)
        net.backward(x_batch, dp)
            
        # Update weights
        sgd_momentum(net.getParameters(), 
                     net.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)      
        
        loss_epoch.append(loss)
        
        # Test prediction & Accuracy
    net.evaluate()
    loss_history(net.forward(X_val))

# %%
#features : 'number of examples' * 'dimensionality'
f = activations[-1]

import scipy.spatial
#compute pairwise distances
d = scipy.spatial.distance_matrix(f,f)
#extract distances for the 'positive pairs' (same class), 
#extract distances for the 'negarite pairs' (different classes), 
a = np.tile(labels.reshape(len(labels), 1), (1, len(labels)))
b =np.tile(labels.reshape(1, len(labels)), (len(labels), 1))
#labels
c = np.zeros((len(labels), len(labels)))
c[a==b]=1
pind =  np.triu(c, k=1)

c = np.zeros((len(labels), len(labels)))
c[a!=b]=1
nind =  np.triu(c, k=1)

print(np.sum(pind), np.sum(nind))


pd = d[pind == 1]
nd = d[nind == 1]

hp,_,_ =plt.hist(pd, bins=100, color='green', alpha = 0.3, weights = np.ones(len(pd))/len(pd), label = 'distances for positive pairs')
hn,_,_ =plt.hist(nd, bins=100, color='red', alpha = 0.3, weights = np.ones(len(nd))/len(nd),label = 'distances for negative pairs')
plt.legend(loc='best')

bhattacharyya = np.sum(np.sqrt(hp*hn))
